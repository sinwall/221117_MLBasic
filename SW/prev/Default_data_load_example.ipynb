# %% [markdown]
# # Default load data example

# %%
from data_loader_default import load_data_default

# %%
load_data = load_data_default(path='./input/default of credit card clients.xls')

# %% [markdown]
# path goes in to line as this:
# ```python
# pd.read_excel(path,header=1)
# ```

# %%
for X_train,y_train,X_val,y_val in load_data.yield_data():
    X_train,y_train = X_train,y_train
    X_val,y_val = X_val,y_val
    print('\n',X_train.SEX.mean(),'\n',X_val.SEX.mean(),'\n',y_train.mean(),'\n',y_val.mean())
    print('\n')
# Out:
#  1.6047777777777779
#  1.5995555555555556
#  0.2212222222222222
#  0.22111111111111112
#
#
#
#  1.6031666666666666
#  1.606
#  0.2212222222222222
#  0.22111111111111112
#
#
#
#  1.6042777777777777
#  1.6015555555555556
#  0.2212222222222222
#  0.22111111111111112
#
#
#
#  1.6019444444444444
#  1.6108888888888888
#  0.22116666666666668
#  0.22133333333333333
#
#
#
#  1.6045
#  1.6006666666666667
#  0.22116666666666668
#  0.22133333333333333

# %%
load_data.df_train
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 20349  20350      80000    1          1         2   25      2      2     -2
# 6983    6984     300000    2          1         1   51     -1     -1     -1
# 17548  17549      60000    2          2         1   48      0      0      0
# 954      955     110000    2          2         1   46     -1     -1     -1
# 12866  12867      20000    2          2         2   25      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 22066  22067     160000    2          1         2   26     -1     -1     -1
# 19277  19278      80000    2          2         1   41     -1     -1     -1
# 23975  23976      20000    1          1         2   25      0      0      0
# 12381  12382     500000    2          1         2   35      1     -1     -1
# 26237  26238     440000    2          2         2   28      0      0      0
#
# ...

# %% [markdown]
# check manuel for further methods

# %%
help(load_data_default)
# Out:
# Help on class load_data_default in module data_loader_default:
#
# class load_data_default(builtins.object)
#  |  load_data_default(path='./input/default of credit card clients.xls', random_state=42)
#  |
#  |  self.df_train : non test data
#  |  self.StratifiedKFold : StratifiedKFold with fixed data and parameter
#  |  self.split : split method of StratifiedKFold with fixed data and parameter thus don't need parameters
#  |  self.yield yields X_train,y_train,X_val,y_val
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, path='./input/default of credit card clients.xls', random_state=42)
#  |      path = path of input data eg: ./input/ default of credit card clients.xls
#  |      (path goes into pd.read_excel(path,header=1)
#  |      random state should be fixed for collab. purpose
#  |
#  |      Note
#  |      load_data_default goes through renaming process
#  |      1.indexing of discrete PAY
#  |      2.BILL_AMTn to BILL_AMT_n
#  |      3.same for PAY_AMT
#  |
# ...

# %% [markdown]
# ### Attributes are list of column names of corresoponding category
# usage:
# ```python
# train_X[D_PAY+L_PAY]
# train_X[USAGE]
# ```
